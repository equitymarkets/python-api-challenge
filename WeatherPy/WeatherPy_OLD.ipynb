# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 614

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
 # Set the API base URL
url = 'http://api.openweathermap.org/data/2.5/weather?'
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1




response = requests.get(city_url)

response_json = response.json() #['cnt']

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
        
    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + '&q=' + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    
    # Add 1 to the record count
    record_count += 1
    
    response = requests.get(city_url)

    response_json = response.json() 
    
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = response.json()['weather']
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = response.json()['coord']['lat']
        city_lng = response.json()['coord']['lon']
        city_max_temp = response.json()['main']['temp_max']
        city_humidity = response.json()['main']['humidity']
        city_clouds = response.json()['clouds']
        city_wind = response.json()['wind']
        city_country = response.json()['sys']['country']
        city_date = response.json()['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | pasni
# Processing Record 3 of Set 1 | saint-augustin
# Processing Record 4 of Set 1 | huntsville
# Processing Record 5 of Set 1 | uusikaupunki
# Processing Record 6 of Set 1 | okha
# Processing Record 7 of Set 1 | georgetown
# Processing Record 8 of Set 1 | port alfred
# Processing Record 9 of Set 1 | otradnoye
# Processing Record 10 of Set 1 | east london
# Processing Record 11 of Set 1 | alta floresta
# Processing Record 12 of Set 1 | cookshire
# City not found. Skipping...
# Processing Record 13 of Set 1 | riyadh
# Processing Record 14 of Set 1 | saryg-sep
# Processing Record 15 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 16 of Set 1 | kapaa
# Processing Record 17 of Set 1 | pochutla
# Processing Record 18 of Set 1 | naze
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | roald
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | pitimbu
# Processing Record 23 of Set 1 | tiksi
# Processing Record 24 of Set 1 | baiyin
# Processing Record 25 of Set 1 | faanui
# Processing Record 26 of Set 1 | madimba
# Processing Record 27 of Set 1 | vaini
# Processing Record 28 of Set 1 | vila do maio
# Processing Record 29 of Set 1 | iqaluit
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | aitape
# Processing Record 32 of Set 1 | mataura
# Processing Record 33 of Set 1 | cape town
# Processing Record 34 of Set 1 | belaya gora
# Processing Record 35 of Set 1 | puerto el triunfo
# Processing Record 36 of Set 1 | sarny
# Processing Record 37 of Set 1 | trairi
# Processing Record 38 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 1 | zhigansk
# Processing Record 40 of Set 1 | umm kaddadah
# Processing Record 41 of Set 1 | dikson
# Processing Record 42 of Set 1 | verkh-usugli
# Processing Record 43 of Set 1 | hay river
# Processing Record 44 of Set 1 | ushuaia
# Processing Record 45 of Set 1 | torbay
# Processing Record 46 of Set 1 | arraial do cabo
# Processing Record 47 of Set 1 | nanakuli
# Processing Record 48 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 1 | atuona
# Processing Record 50 of Set 1 | ardistan
# City not found. Skipping...
# Processing Record 0 of Set 2 | coihaique
# Processing Record 1 of Set 2 | ribeira grande
# Processing Record 2 of Set 2 | kaeo
# Processing Record 3 of Set 2 | jian
# Processing Record 4 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 2 | qaanaaq
# Processing Record 6 of Set 2 | lagoa
# Processing Record 7 of Set 2 | qaqortoq
# Processing Record 8 of Set 2 | yar-sale
# Processing Record 9 of Set 2 | dingle
# Processing Record 10 of Set 2 | chicama
# Processing Record 11 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 2 | pangnirtung
# Processing Record 13 of Set 2 | severo-kurilsk
# Processing Record 14 of Set 2 | vardo
# Processing Record 15 of Set 2 | tuktoyaktuk
# Processing Record 16 of Set 2 | paamiut
# Processing Record 17 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 2 | souillac
# Processing Record 19 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 2 | satitoa
# City not found. Skipping...
# Processing Record 21 of Set 2 | kavieng
# Processing Record 22 of Set 2 | narsaq
# Processing Record 23 of Set 2 | caravelas
# Processing Record 24 of Set 2 | jewar
# Processing Record 25 of Set 2 | kingman
# Processing Record 26 of Set 2 | luderitz
# Processing Record 27 of Set 2 | hilo
# Processing Record 28 of Set 2 | inongo
# Processing Record 29 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 2 | port hardy
# Processing Record 32 of Set 2 | castro
# Processing Record 33 of Set 2 | avarua
# Processing Record 34 of Set 2 | samur
# Processing Record 35 of Set 2 | dwarka
# Processing Record 36 of Set 2 | zhangye
# Processing Record 37 of Set 2 | dianopolis
# City not found. Skipping...
# Processing Record 38 of Set 2 | bredasdorp
# Processing Record 39 of Set 2 | vila franca do campo
# Processing Record 40 of Set 2 | akcaabat
# Processing Record 41 of Set 2 | san cristobal
# Processing Record 42 of Set 2 | biltine
# Processing Record 43 of Set 2 | gravdal
# Processing Record 44 of Set 2 | arlit
# Processing Record 45 of Set 2 | pita
# Processing Record 46 of Set 2 | kahului
# Processing Record 47 of Set 2 | iisalmi
# Processing Record 48 of Set 2 | el jicaro
# Processing Record 49 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 0 of Set 3 | jinka
# Processing Record 1 of Set 3 | ariquemes
# Processing Record 2 of Set 3 | ranong
# Processing Record 3 of Set 3 | mocuba
# Processing Record 4 of Set 3 | bac lieu
# Processing Record 5 of Set 3 | liberal
# Processing Record 6 of Set 3 | puerto ayora
# Processing Record 7 of Set 3 | hermanus
# Processing Record 8 of Set 3 | saint-pierre
# Processing Record 9 of Set 3 | punta arenas
# Processing Record 10 of Set 3 | akhisar
# Processing Record 11 of Set 3 | richmond
# Processing Record 12 of Set 3 | poum
# Processing Record 13 of Set 3 | walvis bay
# Processing Record 14 of Set 3 | pleven
# Processing Record 15 of Set 3 | jardim
# Processing Record 16 of Set 3 | oakdale
# Processing Record 17 of Set 3 | ponta do sol
# Processing Record 18 of Set 3 | inhambane
# Processing Record 19 of Set 3 | shiraz
# Processing Record 20 of Set 3 | formoso do araguaia
# City not found. Skipping...
# Processing Record 21 of Set 3 | chancay
# Processing Record 22 of Set 3 | humberto de campos
# Processing Record 23 of Set 3 | isangel
# Processing Record 24 of Set 3 | jamestown
# Processing Record 25 of Set 3 | bluff
# Processing Record 26 of Set 3 | victoria
# Processing Record 27 of Set 3 | svetlyy
# Processing Record 28 of Set 3 | upornaya
# Processing Record 29 of Set 3 | sarh
# Processing Record 30 of Set 3 | springdale
# Processing Record 31 of Set 3 | thompson
# Processing Record 32 of Set 3 | rongcheng
# Processing Record 33 of Set 3 | new norfolk
# Processing Record 34 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 3 | flinders
# Processing Record 36 of Set 3 | liusha
# Processing Record 37 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 3 | san quintin
# Processing Record 39 of Set 3 | nikolskoye
# Processing Record 40 of Set 3 | kaitangata
# Processing Record 41 of Set 3 | mount gambier
# Processing Record 42 of Set 3 | coquimbo
# Processing Record 43 of Set 3 | alamogordo
# Processing Record 44 of Set 3 | vanimo
# Processing Record 45 of Set 3 | college
# Processing Record 46 of Set 3 | zarand
# Processing Record 47 of Set 3 | hobart
# Processing Record 48 of Set 3 | lompoc
# Processing Record 49 of Set 3 | murray bridge
# Processing Record 0 of Set 4 | tasiilaq
# Processing Record 1 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 2 of Set 4 | pinega
# Processing Record 3 of Set 4 | zeya
# Processing Record 4 of Set 4 | port elizabeth
# Processing Record 5 of Set 4 | provideniya
# Processing Record 6 of Set 4 | los llanos de aridane
# Processing Record 7 of Set 4 | ostrovnoy
# Processing Record 8 of Set 4 | pisco
# Processing Record 9 of Set 4 | grand gaube
# Processing Record 10 of Set 4 | chojnice
# Processing Record 11 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 4 | nizhniy tsasuchey
# Processing Record 13 of Set 4 | bandipur
# Processing Record 14 of Set 4 | pocri
# Processing Record 15 of Set 4 | hambantota
# Processing Record 16 of Set 4 | longyearbyen
# Processing Record 17 of Set 4 | sungai besar
# Processing Record 18 of Set 4 | fortuna
# Processing Record 19 of Set 4 | arrecife
# Processing Record 20 of Set 4 | bangkalan
# Processing Record 21 of Set 4 | auburn
# Processing Record 22 of Set 4 | camacha
# Processing Record 23 of Set 4 | bridlington
# Processing Record 24 of Set 4 | zhangjiakou
# Processing Record 25 of Set 4 | nanortalik
# Processing Record 26 of Set 4 | abay
# Processing Record 27 of Set 4 | leningradskiy
# Processing Record 28 of Set 4 | moen
# Processing Record 29 of Set 4 | ust-ishim
# Processing Record 30 of Set 4 | shenzhen
# Processing Record 31 of Set 4 | hervey bay
# Processing Record 32 of Set 4 | bambous virieux
# Processing Record 33 of Set 4 | lavrentiya
# Processing Record 34 of Set 4 | riobamba
# Processing Record 35 of Set 4 | kodiak
# Processing Record 36 of Set 4 | chokurdakh
# Processing Record 37 of Set 4 | clyde river
# Processing Record 38 of Set 4 | quatre cocos
# Processing Record 39 of Set 4 | airai
# Processing Record 40 of Set 4 | marawi
# Processing Record 41 of Set 4 | san francisco
# Processing Record 42 of Set 4 | ayan
# Processing Record 43 of Set 4 | makhachkala
# Processing Record 44 of Set 4 | meru
# Processing Record 45 of Set 4 | erenhot
# Processing Record 46 of Set 4 | sioux lookout
# Processing Record 47 of Set 4 | busselton
# Processing Record 48 of Set 4 | ambon
# Processing Record 49 of Set 4 | gagarin
# Processing Record 0 of Set 5 | okhotsk
# Processing Record 1 of Set 5 | carnarvon
# Processing Record 2 of Set 5 | mar del plata
# Processing Record 3 of Set 5 | bethel
# Processing Record 4 of Set 5 | saint-philippe
# Processing Record 5 of Set 5 | ancud
# Processing Record 6 of Set 5 | zhanakorgan
# Processing Record 7 of Set 5 | maumere
# Processing Record 8 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 5 | chongqing
# Processing Record 10 of Set 5 | codrington
# Processing Record 11 of Set 5 | jangipur
# Processing Record 12 of Set 5 | nome
# Processing Record 13 of Set 5 | damietta
# Processing Record 14 of Set 5 | namibe
# Processing Record 15 of Set 5 | lephepe
# City not found. Skipping...
# Processing Record 16 of Set 5 | bagepalli
# Processing Record 17 of Set 5 | bhopal
# Processing Record 18 of Set 5 | popondetta
# Processing Record 19 of Set 5 | newport
# Processing Record 20 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 5 | camana
# Processing Record 22 of Set 5 | cherskiy
# Processing Record 23 of Set 5 | dombarovskiy
# Processing Record 24 of Set 5 | muisne
# Processing Record 25 of Set 5 | anapskaya
# Processing Record 26 of Set 5 | fukue
# Processing Record 27 of Set 5 | altamira
# Processing Record 28 of Set 5 | zolotinka
# City not found. Skipping...
# Processing Record 29 of Set 5 | saint george
# Processing Record 30 of Set 5 | cidreira
# Processing Record 31 of Set 5 | zlitan
# Processing Record 32 of Set 5 | miranda
# Processing Record 33 of Set 5 | paracatu
# Processing Record 34 of Set 5 | gamba
# Processing Record 35 of Set 5 | dhanbad
# Processing Record 36 of Set 5 | holovyne
# Processing Record 37 of Set 5 | pueblo nuevo
# Processing Record 38 of Set 5 | vestmannaeyjar
# Processing Record 39 of Set 5 | guasdualito
# Processing Record 40 of Set 5 | hualmay
# Processing Record 41 of Set 5 | banda aceh
# Processing Record 42 of Set 5 | goya
# Processing Record 43 of Set 5 | lamu
# Processing Record 44 of Set 5 | gejiu
# Processing Record 45 of Set 5 | ondangwa
# Processing Record 46 of Set 5 | kirakira
# Processing Record 47 of Set 5 | upernavik
# Processing Record 48 of Set 5 | kamskoye ustye
# Processing Record 49 of Set 5 | dudinka
# Processing Record 0 of Set 6 | barrow
# Processing Record 1 of Set 6 | faya
# Processing Record 2 of Set 6 | liverpool
# Processing Record 3 of Set 6 | kyzyl-suu
# Processing Record 4 of Set 6 | diamantina
# Processing Record 5 of Set 6 | joshimath
# Processing Record 6 of Set 6 | khipro
# Processing Record 7 of Set 6 | mayumba
# Processing Record 8 of Set 6 | chuy
# Processing Record 9 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 10 of Set 6 | ponta delgada
# Processing Record 11 of Set 6 | touros
# Processing Record 12 of Set 6 | vacaville
# Processing Record 13 of Set 6 | kendari
# Processing Record 14 of Set 6 | isla mujeres
# Processing Record 15 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 6 | saint-joseph
# Processing Record 17 of Set 6 | uslar
# Processing Record 18 of Set 6 | bethanien
# Processing Record 19 of Set 6 | norman wells
# Processing Record 20 of Set 6 | westport
# Processing Record 21 of Set 6 | methven
# Processing Record 22 of Set 6 | aklavik
# Processing Record 23 of Set 6 | makubetsu
# Processing Record 24 of Set 6 | stornoway
# Processing Record 25 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 26 of Set 6 | orlik
# Processing Record 27 of Set 6 | kulhudhuffushi
# Processing Record 28 of Set 6 | hithadhoo
# Processing Record 29 of Set 6 | hamilton
# Processing Record 30 of Set 6 | lebu
# Processing Record 31 of Set 6 | rafaela
# Processing Record 32 of Set 6 | rottingdean
# Processing Record 33 of Set 6 | porto novo
# Processing Record 34 of Set 6 | kuito
# Processing Record 35 of Set 6 | nabire
# Processing Record 36 of Set 6 | manbij
# Processing Record 37 of Set 6 | makakilo city
# Processing Record 38 of Set 6 | jiuquan
# Processing Record 39 of Set 6 | rohatyn
# Processing Record 40 of Set 6 | sibolga
# Processing Record 41 of Set 6 | pakokku
# Processing Record 42 of Set 6 | huarmey
# Processing Record 43 of Set 6 | cabo san lucas
# Processing Record 44 of Set 6 | uberlandia
# Processing Record 45 of Set 6 | moramanga
# Processing Record 46 of Set 6 | funes
# Processing Record 47 of Set 6 | tamale
# Processing Record 48 of Set 6 | peniche
# Processing Record 49 of Set 6 | mocambique
# City not found. Skipping...
# Processing Record 0 of Set 7 | dali
# Processing Record 1 of Set 7 | esperance
# Processing Record 2 of Set 7 | bernalillo
# Processing Record 3 of Set 7 | saskylakh
# Processing Record 4 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 7 | presidencia roque saenz pena
# Processing Record 6 of Set 7 | inuvik
# Processing Record 7 of Set 7 | maxixe
# Processing Record 8 of Set 7 | jedrzejow
# Processing Record 9 of Set 7 | ust-nera
# Processing Record 10 of Set 7 | matagami
# Processing Record 11 of Set 7 | jabiru
# City not found. Skipping...
# Processing Record 12 of Set 7 | bressanone
# Processing Record 13 of Set 7 | bairiki
# Processing Record 14 of Set 7 | te anau
# Processing Record 15 of Set 7 | lata
# Processing Record 16 of Set 7 | chikwawa
# Processing Record 17 of Set 7 | teruel
# Processing Record 18 of Set 7 | dallas
# Processing Record 19 of Set 7 | coban
# Processing Record 20 of Set 7 | husavik
# Processing Record 21 of Set 7 | mwandiga
# Processing Record 22 of Set 7 | houma
# Processing Record 23 of Set 7 | sao filipe
# Processing Record 24 of Set 7 | butaritari
# Processing Record 25 of Set 7 | vera cruz
# Processing Record 26 of Set 7 | grindavik
# Processing Record 27 of Set 7 | qasigiannguit
# Processing Record 28 of Set 7 | kautokeino
# Processing Record 29 of Set 7 | dawlatabad
# Processing Record 30 of Set 7 | penzance
# Processing Record 31 of Set 7 | champerico
# Processing Record 32 of Set 7 | leh
# Processing Record 33 of Set 7 | montepuez
# Processing Record 34 of Set 7 | itarantim
# Processing Record 35 of Set 7 | port augusta
# Processing Record 36 of Set 7 | tomatlan
# Processing Record 37 of Set 7 | egvekinot
# Processing Record 38 of Set 7 | alofi
# Processing Record 39 of Set 7 | avera
# Processing Record 40 of Set 7 | bengkulu
# Processing Record 41 of Set 7 | bokspits
# City not found. Skipping...
# Processing Record 42 of Set 7 | khatanga
# Processing Record 43 of Set 7 | jahrom
# City not found. Skipping...
# Processing Record 44 of Set 7 | teahupoo
# Processing Record 45 of Set 7 | tessalit
# Processing Record 46 of Set 7 | tuy hoa
# Processing Record 47 of Set 7 | shenjiamen
# Processing Record 48 of Set 7 | karratha
# Processing Record 49 of Set 7 | camopi
# Processing Record 0 of Set 8 | nelson bay
# Processing Record 1 of Set 8 | jinchang
# Processing Record 2 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 8 | tigveni
# Processing Record 4 of Set 8 | evensk
# Processing Record 5 of Set 8 | geraldton
# Processing Record 6 of Set 8 | cristalina
# Processing Record 7 of Set 8 | richards bay
# Processing Record 8 of Set 8 | grande prairie
# Processing Record 9 of Set 8 | svetlogorsk
# Processing Record 10 of Set 8 | jaragua
# Processing Record 11 of Set 8 | vila real de santo antonio
# Processing Record 12 of Set 8 | mehamn
# Processing Record 13 of Set 8 | kavaratti
# Processing Record 14 of Set 8 | neryungri
# Processing Record 15 of Set 8 | muzquiz
# City not found. Skipping...
# Processing Record 16 of Set 8 | malpe
# Processing Record 17 of Set 8 | bursa
# Processing Record 18 of Set 8 | nouadhibou
# Processing Record 19 of Set 8 | jujuy
# City not found. Skipping...
# Processing Record 20 of Set 8 | canete
# Processing Record 21 of Set 8 | marzuq
# Processing Record 22 of Set 8 | balykshi
# Processing Record 23 of Set 8 | nalut
# Processing Record 24 of Set 8 | ballina
# Processing Record 25 of Set 8 | la vega
# Processing Record 26 of Set 8 | pacific grove
# Processing Record 27 of Set 8 | birjand
# Processing Record 28 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 29 of Set 8 | innisfail
# Processing Record 30 of Set 8 | acin
# City not found. Skipping...
# Processing Record 31 of Set 8 | oranjestad
# Processing Record 32 of Set 8 | thinadhoo
# Processing Record 33 of Set 8 | karauzyak
# City not found. Skipping...
# Processing Record 34 of Set 8 | sao joao da barra
# Processing Record 35 of Set 8 | doha
# Processing Record 36 of Set 8 | terebovlya
# Processing Record 37 of Set 8 | fort-shevchenko
# Processing Record 38 of Set 8 | wairoa
# Processing Record 39 of Set 8 | dawson creek
# Processing Record 40 of Set 8 | broken hill
# Processing Record 41 of Set 8 | monteagudo
# Processing Record 42 of Set 8 | san patricio
# Processing Record 43 of Set 8 | gazanjyk
# Processing Record 44 of Set 8 | bulawayo
# Processing Record 45 of Set 8 | yanan
# City not found. Skipping...
# Processing Record 46 of Set 8 | nador
# Processing Record 47 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 48 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 49 of Set 8 | tefe
# Processing Record 0 of Set 9 | rusne
# Processing Record 1 of Set 9 | marsa matruh
# Processing Record 2 of Set 9 | huilong
# Processing Record 3 of Set 9 | la primavera
# Processing Record 4 of Set 9 | anito
# Processing Record 5 of Set 9 | goderich
# Processing Record 6 of Set 9 | standerton
# Processing Record 7 of Set 9 | tsiroanomandidy
# Processing Record 8 of Set 9 | hofn
# Processing Record 9 of Set 9 | atbasar
# Processing Record 10 of Set 9 | ola
# Processing Record 11 of Set 9 | san juan
# Processing Record 12 of Set 9 | klaksvik
# Processing Record 13 of Set 9 | nuuk
# Processing Record 14 of Set 9 | sitka
# Processing Record 15 of Set 9 | guerrero negro
# Processing Record 16 of Set 9 | manica
# Processing Record 17 of Set 9 | dunedin
# Processing Record 18 of Set 9 | nyurba
# Processing Record 19 of Set 9 | san andres
# Processing Record 20 of Set 9 | mariinsk
# Processing Record 21 of Set 9 | tari
# Processing Record 22 of Set 9 | altay
# Processing Record 23 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 24 of Set 9 | mandera
# Processing Record 25 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 26 of Set 9 | ulladulla
# Processing Record 27 of Set 9 | constitucion
# Processing Record 28 of Set 9 | chapais
# Processing Record 29 of Set 9 | jalu
# Processing Record 30 of Set 9 | homer
# Processing Record 31 of Set 9 | salalah
# Processing Record 32 of Set 9 | nhulunbuy
# Processing Record 33 of Set 9 | brighton
# Processing Record 34 of Set 9 | hasaki
# Processing Record 35 of Set 9 | novoagansk
# Processing Record 36 of Set 9 | pallasovka
# Processing Record 37 of Set 9 | belmonte
# Processing Record 38 of Set 9 | lixourion
# Processing Record 39 of Set 9 | talnakh
# Processing Record 40 of Set 9 | mount isa
# Processing Record 41 of Set 9 | ugoofaaru
# Processing Record 42 of Set 9 | kununurra
# Processing Record 43 of Set 9 | katsuura
# Processing Record 44 of Set 9 | visnes
# Processing Record 45 of Set 9 | taltal
# Processing Record 46 of Set 9 | balakhta
# Processing Record 47 of Set 9 | tura
# Processing Record 48 of Set 9 | tonj
# Processing Record 49 of Set 9 | nara
# Processing Record 0 of Set 10 | binalan
# Processing Record 1 of Set 10 | merauke
# Processing Record 2 of Set 10 | vila velha
# Processing Record 3 of Set 10 | lyubar
# Processing Record 4 of Set 10 | iquitos
# Processing Record 5 of Set 10 | yinchuan
# Processing Record 6 of Set 10 | butka
# Processing Record 7 of Set 10 | mackay
# Processing Record 8 of Set 10 | kutum
# Processing Record 9 of Set 10 | saldanha
# Processing Record 10 of Set 10 | muros
# Processing Record 11 of Set 10 | aljezur
# Processing Record 12 of Set 10 | mahebourg
# Processing Record 13 of Set 10 | ferme-neuve
# Processing Record 14 of Set 10 | martapura
# Processing Record 15 of Set 10 | kresek
# Processing Record 16 of Set 10 | coruripe
# Processing Record 17 of Set 10 | olga
# Processing Record 18 of Set 10 | huanan
# Processing Record 19 of Set 10 | aden
# Processing Record 20 of Set 10 | bilma
# Processing Record 21 of Set 10 | bowen
# Processing Record 22 of Set 10 | nsanje
# Processing Record 23 of Set 10 | tapaua
# City not found. Skipping...
# Processing Record 24 of Set 10 | one hundred mile house
# City not found. Skipping...
# Processing Record 25 of Set 10 | salinopolis
# Processing Record 26 of Set 10 | mandalgovi
# Processing Record 27 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 28 of Set 10 | puerto ayacucho
# Processing Record 29 of Set 10 | sanmenxia
# Processing Record 30 of Set 10 | manta
# Processing Record 31 of Set 10 | filadelfia
# Processing Record 32 of Set 10 | abu samrah
# Processing Record 33 of Set 10 | owensboro
# Processing Record 34 of Set 10 | algiers
# Processing Record 35 of Set 10 | ayoquezco
# City not found. Skipping...
# Processing Record 36 of Set 10 | upington
# Processing Record 37 of Set 10 | mujiayingzi
# Processing Record 38 of Set 10 | namwala
# Processing Record 39 of Set 10 | beringovskiy
# Processing Record 40 of Set 10 | chernyshevskiy
# Processing Record 41 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 42 of Set 10 | devgarh
# Processing Record 43 of Set 10 | araouane
# Processing Record 44 of Set 10 | padang
# Processing Record 45 of Set 10 | santa cruz
# Processing Record 46 of Set 10 | sambava
# Processing Record 47 of Set 10 | roma
# Processing Record 48 of Set 10 | dalaba
# Processing Record 49 of Set 10 | bilibino
# Processing Record 0 of Set 11 | atambua
# Processing Record 1 of Set 11 | parana
# Processing Record 2 of Set 11 | tuatapere
# Processing Record 3 of Set 11 | shingu
# Processing Record 4 of Set 11 | lubango
# Processing Record 5 of Set 11 | quesnel
# Processing Record 6 of Set 11 | tateyama
# Processing Record 7 of Set 11 | viet tri
# Processing Record 8 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 9 of Set 11 | vao
# Processing Record 10 of Set 11 | mayskiy
# Processing Record 11 of Set 11 | iquique
# Processing Record 12 of Set 11 | ketchikan
# Processing Record 13 of Set 11 | faranah
# Processing Record 14 of Set 11 | yanchukan
# City not found. Skipping...
# Processing Record 15 of Set 11 | sri aman
# Processing Record 16 of Set 11 | bathsheba
# Processing Record 17 of Set 11 | mayo
# Processing Record 18 of Set 11 | onega
# Processing Record 19 of Set 11 | rawson
# Processing Record 20 of Set 11 | santa luzia
# Processing Record 21 of Set 11 | shubarkuduk
# Processing Record 22 of Set 11 | namatanai
# Processing Record 23 of Set 11 | keuruu
# Processing Record 24 of Set 11 | bonthe
# Processing Record 25 of Set 11 | nisia floresta
# Processing Record 26 of Set 11 | cayenne
# Processing Record 27 of Set 11 | saint-francois
# Processing Record 28 of Set 11 | mgandu
# Processing Record 29 of Set 11 | kamaishi
# Processing Record 30 of Set 11 | sumbawanga
# Processing Record 31 of Set 11 | oktyabrskiy
# Processing Record 32 of Set 11 | kieta
# Processing Record 33 of Set 11 | freetown
# Processing Record 34 of Set 11 | wajima
# Processing Record 35 of Set 11 | bonavista
# Processing Record 36 of Set 11 | rassvet
# Processing Record 37 of Set 11 | pevek
# Processing Record 38 of Set 11 | borlange
# City not found. Skipping...
# Processing Record 39 of Set 11 | deloraine
# Processing Record 40 of Set 11 | cukai
# Processing Record 41 of Set 11 | amboasary
# Processing Record 42 of Set 11 | oparino
# Processing Record 43 of Set 11 | chake chake
# Processing Record 44 of Set 11 | chara
# Processing Record 45 of Set 11 | ipora
# Processing Record 46 of Set 11 | cullera
# Processing Record 47 of Set 11 | tutoia
# Processing Record 48 of Set 11 | samarai
# Processing Record 49 of Set 11 | niquelandia
# Processing Record 0 of Set 12 | finschhafen
# Processing Record 1 of Set 12 | hami
# Processing Record 2 of Set 12 | acarau
# Processing Record 3 of Set 12 | alvand
# Processing Record 4 of Set 12 | kropotkin
# Processing Record 5 of Set 12 | margate
# Processing Record 6 of Set 12 | cape coast
# Processing Record 7 of Set 12 | anadyr
# Processing Record 8 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 9 of Set 12 | sibu
# Processing Record 10 of Set 12 | cacu
# Processing Record 11 of Set 12 | arman
# Processing Record 12 of Set 12 | tahoua
# Processing Record 13 of Set 12 | stromness
# Processing Record 14 of Set 12 | noumea
# Processing Record 15 of Set 12 | batemans bay
# Processing Record 16 of Set 12 | cap-haitien
# Processing Record 17 of Set 12 | asheboro
# Processing Record 18 of Set 12 | severomuysk
# Processing Record 19 of Set 12 | pingzhuang
# Processing Record 20 of Set 12 | bandarbeyla
# Processing Record 21 of Set 12 | marfino
# Processing Record 22 of Set 12 | jakar
# Processing Record 23 of Set 12 | otjiwarongo
# Processing Record 24 of Set 12 | fuerte olimpo
# Processing Record 25 of Set 12 | sechura
# Processing Record 26 of Set 12 | kedrovyy
# Processing Record 27 of Set 12 | dubbo
# Processing Record 28 of Set 12 | edendale
# Processing Record 29 of Set 12 | twin falls
# Processing Record 30 of Set 12 | poli
# Processing Record 31 of Set 12 | tevaitoa
# Processing Record 32 of Set 12 | ocampo
# Processing Record 33 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 12 | kostomuksha
# Processing Record 35 of Set 12 | kruisfontein
# Processing Record 36 of Set 12 | dannenberg
# Processing Record 37 of Set 12 | inta
# Processing Record 38 of Set 12 | compiegne
# Processing Record 39 of Set 12 | galesong
# Processing Record 40 of Set 12 | yanam
# Processing Record 41 of Set 12 | saint anthony
# Processing Record 42 of Set 12 | basco
# Processing Record 43 of Set 12 | comodoro rivadavia
# Processing Record 44 of Set 12 | sinnamary
# Processing Record 45 of Set 12 | teeli
# Processing Record 46 of Set 12 | abha
# Processing Record 47 of Set 12 | ous
# Processing Record 48 of Set 12 | nishihara
# Processing Record 49 of Set 12 | nelson
# Processing Record 0 of Set 13 | serik
# Processing Record 1 of Set 13 | pagudpud
# Processing Record 2 of Set 13 | komsomolskiy
# Processing Record 3 of Set 13 | sarakhs
# Processing Record 4 of Set 13 | ucluelet
# Processing Record 5 of Set 13 | istisu
# Processing Record 6 of Set 13 | lebowakgomo
# Processing Record 7 of Set 13 | la ronge
# Processing Record 8 of Set 13 | fare
# Processing Record 9 of Set 13 | carutapera
# Processing Record 10 of Set 13 | pendleton
# Processing Record 11 of Set 13 | tome-acu
# City not found. Skipping...
# Processing Record 12 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 13 of Set 13 | lufilufi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame()

# Show Record Count
city_data_df.count()

# %%
# Display sample data
city_data_df.head()

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
